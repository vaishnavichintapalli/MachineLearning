# %%
import os                                                                                 #10/6/2019_vaishnavi.ch_jntusampledataassignment
os.getcwd()
# Out:
# 'C:\\Users\\saima\\Desktop\\Datascience'

# %%
os.chdir("C:/Users/saima/Desktop/Datascience")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\saima\\Desktop\\Datascience'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import scipy
from scipy.stats.stats import pearsonr

# %%
jntu=pd.read_csv("JNTU Sample data.csv")
jntu
# Out:
#             State Division         Region        Branch RouteCode  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur  KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# ...

# %%
jntu.head()
# Out:
#        State Division        Region        Branch RouteCode      VillageName  \
# 0  Karnataka    KA 02  GOWRIBIDANUR  Gowribidanur  KGAWGAWD  Ramachandrapura
# 1  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2  KVIJVIBC   sadapana halli
# 2  Karnataka    KA 01   VIJAYAPURAM   Vijaypura-2  KVIJVIBC        yanagante
# 3  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2  KVIJVIBC        yanagante
# 4  Karnataka    KA 02   VIJAYAPURAM   Vijaypura-2  KVIJVIBC       sathyavara
#
#    pincode         CenterName  Group Name                  Name  Loannature  \
# 0   504273    Ramachandrapura        Rama       Vadand Geetaben           1
# 1   504293  sadapanahalli new  sumithra 1   Co Patel Manjulaben           1
# 2   504307          yanagante  lakshmamma     Ghanchi Aminabibi           1
# 3   504001          yanagante     fincare  Ghanchi Farajanabanu           1
# 4   504001         sathyavara     saibaba  Ghanchee Shabanabanu           1
#
# ...

# %%
jntu.describe()
# Out:
#          pincode  Loannature  ExistingLoanamount        AGE  \
# count  13435.000   13435.000            13435.000 13435.000
# mean  514413.112       1.005           119970.320    33.101
# std     8956.412       0.069            63417.170     8.914
# min   500001.000       1.000            10055.000    18.000
# 25%   506313.000       1.000            64990.000    25.000
# 50%   515832.000       1.000           120668.000    33.000
# 75%   521402.000       1.000           174660.500    41.000
# max   534475.000       2.000           229988.000    48.000
#
#               ADHAARNUMBER
# count            13435.000
# mean  5563283959806483.000
# std   2487175286252995.500
# min   1250000000000000.000
# 25%   3420000000000000.000
# 50%   5550000000000000.000
# 75%   7710000000000000.000
# max   9870000000000000.000

# %%
jntu.dtypes
# Out:
# State                        object
# Division                     object
# Region                       object
# Branch                       object
# RouteCode                    object
# VillageName                  object
# pincode                       int64
# CenterName                   object
# Group Name                   object
# Name                         object
# Loannature                    int64
# Employee Name for clinet     object
# ExistingLoanamount            int64
# Loan Date                    object
# AGE                           int64
# ID_DETAILS                   object
# ADHAARNUMBER                float64
# Marital_Status               object
# INCOMESOURCE                 object
# LoanStatus                   object
# dtype: object

# %%
jntu.columns.get_loc('LoanStatus')
# Out:
# 19

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
jntu.describe()
# Out:
#          pincode  Loannature  ExistingLoanamount        AGE  \
# count  13435.000   13435.000            13435.000 13435.000
# mean  514413.112       1.005           119970.320    33.101
# std     8956.412       0.069            63417.170     8.914
# min   500001.000       1.000            10055.000    18.000
# 25%   506313.000       1.000            64990.000    25.000
# 50%   515832.000       1.000           120668.000    33.000
# 75%   521402.000       1.000           174660.500    41.000
# max   534475.000       2.000           229988.000    48.000
#
#               ADHAARNUMBER
# count            13435.000
# mean  5563283959806483.000
# std   2487175286252995.500
# min   1250000000000000.000
# 25%   3420000000000000.000
# 50%   5550000000000000.000
# 75%   7710000000000000.000
# max   9870000000000000.000

# %% [markdown]
# # data cleaning

# %%
jntu.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# State                          0
# Division                       0
# Region                         0
# Branch                         1
# RouteCode                      0
# VillageName                    0
# pincode                        0
# CenterName                     0
# Group Name                     0
# Name                           0
# Loannature                     0
# Employee Name for clinet       0
# ExistingLoanamount             0
# Loan Date                      0
# AGE                            0
# ID_DETAILS                     0
# ADHAARNUMBER                   0
# Marital_Status                 0
# INCOMESOURCE                3435
# LoanStatus                  4941
# dtype: int64

# %%
a=jntu['Branch'].mode()

# %%
a
# Out:
# 0    Doddaballapur
# dtype: object

# %%
jntu['Branch'].fillna('Doddaballapur',inplace=True)

# %%
jntu.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# State                          0
# Division                       0
# Region                         0
# Branch                         0
# RouteCode                      0
# VillageName                    0
# pincode                        0
# CenterName                     0
# Group Name                     0
# Name                           0
# Loannature                     0
# Employee Name for clinet       0
# ExistingLoanamount             0
# Loan Date                      0
# AGE                            0
# ID_DETAILS                     0
# ADHAARNUMBER                   0
# Marital_Status                 0
# INCOMESOURCE                3435
# LoanStatus                  4941
# dtype: int64

# %%
s=jntu['INCOMESOURCE'].mode()

# %%
s
# Out:
# 0    BUSINESS
# dtype: object

# %%
jntu['INCOMESOURCE'].fillna('BUSINESS',inplace=True)

# %%
T=jntu['LoanStatus'].mode()

# %%
T
# Out:
# 0    YES
# dtype: object

# %%
jntu['LoanStatus'].fillna('YES',inplace=True)

# %%
jntu.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# State                       0
# Division                    0
# Region                      0
# Branch                      0
# RouteCode                   0
# VillageName                 0
# pincode                     0
# CenterName                  0
# Group Name                  0
# Name                        0
# Loannature                  0
# Employee Name for clinet    0
# ExistingLoanamount          0
# Loan Date                   0
# AGE                         0
# ID_DETAILS                  0
# ADHAARNUMBER                0
# Marital_Status              0
# INCOMESOURCE                0
# LoanStatus                  0
# dtype: int64

# %%
jntu.describe()
# Out:
#          pincode  Loannature  ExistingLoanamount        AGE  \
# count  13435.000   13435.000            13435.000 13435.000
# mean  514413.112       1.005           119970.320    33.101
# std     8956.412       0.069            63417.170     8.914
# min   500001.000       1.000            10055.000    18.000
# 25%   506313.000       1.000            64990.000    25.000
# 50%   515832.000       1.000           120668.000    33.000
# 75%   521402.000       1.000           174660.500    41.000
# max   534475.000       2.000           229988.000    48.000
#
#               ADHAARNUMBER
# count            13435.000
# mean  5563283959806483.000
# std   2487175286252995.500
# min   1250000000000000.000
# 25%   3420000000000000.000
# 50%   5550000000000000.000
# 75%   7710000000000000.000
# max   9870000000000000.000

# %% [markdown]
# # exploratory data analysis

# %%
jntu.boxplot(column='ExistingLoanamount ')

# %%
jntu.boxplot(column='AGE')

# %%
jntu.columns
# Out:
# Index(['State', 'Division', 'Region', 'Branch', 'RouteCode', 'VillageName',
#        'pincode', 'CenterName', 'Group Name', 'Name', 'Loannature',
#        'Employee Name for clinet', 'ExistingLoanamount ', 'Loan Date', 'AGE',
#        'ID_DETAILS', 'ADHAARNUMBER', 'Marital_Status', 'INCOMESOURCE',
#        'LoanStatus'],
#       dtype='object')

# %%
jntu.boxplot(column='ADHAARNUMBER')

# %%
jntu.boxplot(column='Loannature')

# %%
jntu.boxplot(column='pincode')

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

labelencoder=LabelEncoder()
jntu['LoanStatus']=labelencoder.fit_transform(jntu['LoanStatus'])
jntu
# Out:
#             State Division         Region        Branch RouteCode  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur  KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# ...

# %%
jntu.corr(method='spearman')
# Out:
#                      pincode  Loannature  ExistingLoanamount     AGE  \
# pincode                1.000      -0.006               -0.005 -0.014
# Loannature            -0.006       1.000                0.019 -0.006
# ExistingLoanamount    -0.005       0.019                1.000  0.004
# AGE                   -0.014      -0.006                0.004  1.000
# ADHAARNUMBER           0.010       0.002                0.019 -0.003
# LoanStatus             0.123      -0.021               -0.002 -0.005
#
#                      ADHAARNUMBER  LoanStatus
# pincode                     0.010       0.123
# Loannature                  0.002      -0.021
# ExistingLoanamount          0.019      -0.002
# AGE                        -0.003      -0.005
# ADHAARNUMBER                1.000       0.000
# LoanStatus                  0.000       1.000

# %%
jntu.hist('Loannature',bins=5),jntu.hist('ExistingLoanamount ',bins=5),jntu.hist('LoanStatus',bins=5)
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FD810B4048>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FD810CC198>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FD81128240>]],
#        dtype=object))

# %%
dt=jntu.head(5)
dt.plot.bar(x='LoanStatus',y='ExistingLoanamount ')

# %%
jntu.corr()
# Out:
#                      pincode  Loannature  ExistingLoanamount     AGE  \
# pincode                1.000      -0.007               -0.002 -0.013
# Loannature            -0.007       1.000                0.019 -0.006
# ExistingLoanamount    -0.002       0.019                1.000  0.004
# AGE                   -0.013      -0.006                0.004  1.000
# ADHAARNUMBER           0.010       0.002                0.019 -0.003
# LoanStatus             0.109      -0.021               -0.002 -0.005
#
#                      ADHAARNUMBER  LoanStatus
# pincode                     0.010       0.109
# Loannature                  0.002      -0.021
# ExistingLoanamount          0.019      -0.002
# AGE                        -0.003      -0.005
# ADHAARNUMBER                1.000       0.000
# LoanStatus                  0.000       1.000

# %%
jntu.dtypes
# Out:
# State                        object
# Division                     object
# Region                       object
# Branch                       object
# RouteCode                    object
# VillageName                  object
# pincode                       int64
# CenterName                   object
# Group Name                   object
# Name                         object
# Loannature                    int64
# Employee Name for clinet     object
# ExistingLoanamount            int64
# Loan Date                    object
# AGE                           int64
# ID_DETAILS                   object
# ADHAARNUMBER                float64
# Marital_Status               object
# INCOMESOURCE                 object
# LoanStatus                    int32
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

labelencoder=LabelEncoder()
jntu['Marital_Status']=labelencoder.fit_transform(jntu['Marital_Status'])
jntu
# Out:
#             State Division         Region        Branch RouteCode  \
# 0       Karnataka    KA 02   GOWRIBIDANUR  Gowribidanur  KGAWGAWD
# 1       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 2       Karnataka    KA 01    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 3       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 4       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 5       Karnataka    KA 02    VIJAYAPURAM   Vijaypura-2  KVIJVIBC
# 6       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 7       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 8       Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 9       Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# 10      Karnataka    KA 02    NELAMANGALA   Nelamangala  KNELNELC
# 11      Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# 12      Karnataka    KA 01          KOLAR     Kolaramma  KKOLKOLB
# ...

# %% [markdown]
# # training and testing data

# %%
x=jntu.iloc[:,[10,12,16,17]].values
y=jntu.iloc[:,[19]].values

# %%
x
# Out:
# array([[1.00000e+00, 1.82050e+05, 8.23000e+15, 1.00000e+00],
#        [1.00000e+00, 1.33250e+04, 5.55000e+15, 1.00000e+00],
#        [1.00000e+00, 1.12780e+05, 3.99000e+15, 1.00000e+00],
#        ...,
#        [1.00000e+00, 5.14760e+04, 8.00000e+15, 1.00000e+00],
#        [1.00000e+00, 1.80678e+05, 6.82000e+15, 1.00000e+00],
#        [1.00000e+00, 5.32490e+04, 4.69000e+15, 1.00000e+00]])

# %%
y
# Out:
# array([[0],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[1.00000e+00, 1.72096e+05, 3.31000e+15, 1.00000e+00],
#        [1.00000e+00, 5.29820e+04, 8.41000e+15, 1.00000e+00],
#        [1.00000e+00, 8.12940e+04, 4.36000e+15, 1.00000e+00],
#        ...,
#        [1.00000e+00, 3.39350e+04, 5.75000e+15, 1.00000e+00],
#        [1.00000e+00, 2.13917e+05, 4.45000e+15, 1.00000e+00],
#        [1.00000e+00, 3.85940e+04, 8.09000e+15, 1.00000e+00]])

# %%
x_test
# Out:
# array([[1.00000e+00, 2.17282e+05, 8.90000e+15, 1.00000e+00],
#        [1.00000e+00, 1.11423e+05, 6.11000e+15, 1.00000e+00],
#        [1.00000e+00, 1.07120e+04, 5.33000e+15, 2.00000e+00],
#        ...,
#        [1.00000e+00, 2.55010e+04, 5.57000e+15, 2.00000e+00],
#        [1.00000e+00, 1.55878e+05, 2.86000e+15, 1.00000e+00],
#        [1.00000e+00, 2.46340e+04, 7.17000e+15, 1.00000e+00]])

# %%
y_train
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %%
y_test
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model.logistic import LogisticRegression

lgsr=LogisticRegression(random_state=0)
lgsr.fit(x_train,y_train)
# Out:
# C:\Users\saima\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\saima\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred=lgsr.predict(x_test)

y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import confusion_matrix
conf_matrix=confusion_matrix(y_pred,y_test)
conf_matrix
# Out:
# array([[   0,    0],
#        [ 503, 2184]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
acc_sco=accuracy_score(y_test,y_pred)
acc_sco
# Out:
# 0.8128023818384815

# %% [markdown]
# # support vector classification

# %%
#Support vector classification
from sklearn.svm import SVC
sc =SVC(kernel='rbf')
sc_classifier=sc.fit(x_train,y_train)
# Out:
# C:\Users\saima\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\saima\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
#Predicting Test and Train data

svc_y_test=sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# [1 1 1 ... 1 1 1]

# %%
#Build a confusion matrix on test and tarin
from sklearn.metrics import confusion_matrix
svc_cm_test=confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[   0,  503],
#        [   0, 2184]], dtype=int64)

# %%
#Accuracy classification score

from sklearn.metrics import accuracy_score
svc_acc_test=accuracy_score(y_test,svc_y_test)
svc_acc_test
# Out:
# 0.8128023818384815

# %% [markdown]
# # decision tree classifier

# %%
#DECISION TREE CLASSIFIER

from sklearn.tree import DecisionTreeClassifier
dtc_clf=DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Predicting on test data

dtc_y_test=dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
#Build confusion matrix on test

from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[ 108,  395],
#        [ 425, 1759]], dtype=int64)

# %%
#Accuracy score on test

from sklearn.metrics import accuracy_score
dtc_accu_test=accuracy_score(y_test,dtc_y_test)
dtc_accu_test
# Out:
# 0.6948269445478229

# %% [markdown]
# # random forest

# %%
#build random forest classifier

from sklearn.ensemble import RandomForestClassifier
rmf=RandomForestClassifier(max_depth=3,random_state=0)
rf_classi=RandomForestClassifier()
rf_classi.fit(x_train,y_train)
# Out:
# C:\Users\saima\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\saima\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf_classi_y_test=dtc_clf.predict(x_test)

rf_classi_y_test
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
rf_cm_test=confusion_matrix(y_test,rf_classi_y_test)
rf_cm_test
# Out:
# array([[ 108,  395],
#        [ 425, 1759]], dtype=int64)

# %%
#Accuracy score on test data

from sklearn.metrics import accuracy_score
rf_accu_test=accuracy_score(y_test,rf_classi_y_test)
rf_accu_test
# Out:
# 0.6948269445478229

# %% [markdown]
# # naive bayes

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(x_train,y_train)
GaussianNB()
print(clf.predict(x_test))
# Out:
# [1 1 1 ... 1 1 1]
# C:\Users\saima\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
nb_classi_y_test=dtc_clf.predict(x_test)

nb_classi_y_test
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
nb_cm_test=confusion_matrix(y_test,rf_classi_y_test)
nb_cm_test
# Out:
# array([[ 108,  395],
#        [ 425, 1759]], dtype=int64)

# %%
#Accuracy score on test data

from sklearn.metrics import accuracy_score
cm_accu_test=accuracy_score(y_test,rf_classi_y_test)
cm_accu_test
# Out:
# 0.6948269445478229
